# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from importlib import reload
import warnings
import common as c
import contestants
import queeneps
import episodes
import wrangle as w

# %%
reload(c)
soups = c.get_soups()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[99], line 2
#       1 reload(c)
# ----> 2 soups = c.get_soups()
#
# File ~/Developer/pydragrace/common.py:41, in get_soups()
#      39 def get_soups() -> Dict[str,List[BeautifulSoup]]:
#      40     series_info = zip(SERIES_NAMES, WIKI_URLS, NO_SEASONS)
# ---> 41     return {name: get_soup(url, seasons) for name, url, seasons in series_info}
#
# File ~/Developer/pydragrace/common.py:41, in <dictcomp>(.0)
#      39 def get_soups() -> Dict[str,List[BeautifulSoup]]:
#      40     series_info = zip(SERIES_NAMES, WIKI_URLS, NO_SEASONS)
# ---> 41     return {name: get_soup(url, seasons) for name, url, seasons in series_info}
#
# File ~/Developer/pydragrace/common.py:35, in get_soup(f_url, no_seasons)
#      33 for season in range(1, no_seasons+1):
#      34     response = requests.get(f_url.format(season)).content
# ...

# %%
reload(contestants)
contestants.get_all_contestants(soups)
# Out:
#             contestant age     outcome  season              series  \
# 0    BeBe Zahara Benet  28      Winner       1  Rupaul's Drag Race
# 1         Nina Flowers  34   Runner-up       1  Rupaul's Drag Race
# 2    Rebecca Glasscock  26   3rd place       1  Rupaul's Drag Race
# 3              Shannel  29   4th place       1  Rupaul's Drag Race
# 4               Ongina  26   5th place       1  Rupaul's Drag Race
# ..                 ...  ..         ...     ...                 ...
# 351              Elips  25   6th Place       1    Drag Race France
# 352           Kam Hugh  22   7th Place       1    Drag Race France
# 353        La Briochée  31   8th Place       1    Drag Race France
# 354        Lova Ladiva  32   9th Place       1    Drag Race France
# 355          La Kahena  29  10th Place       1    Drag Race France
#
#                              city
# 0          Minneapolis, Minnesota
# 1                Denver, Colorado
# 2        Fort Lauderdale, Florida
# ...

# %%
reload(queenep)
queenep.get_all_contep(soups)
# Out:
#       season  episode              queen outcome
# 0          1        1  BeBe Zahara Benet    SAFE
# 1          1        2  BeBe Zahara Benet    SAFE
# 2          1        3  BeBe Zahara Benet     WIN
# 3          1        4  BeBe Zahara Benet    SAFE
# 4          1        5  BeBe Zahara Benet     BTM
# ...      ...      ...                ...     ...
# 2771       1        1        Lova Ladiva     BTM
# 2772       1        2        Lova Ladiva    ELIM
# 2773       1        4        Lova Ladiva   Guest
# 2774       1        1          La Kahena    ELIM
# 2775       1        3          La Kahena   Guest
#
# [2776 rows x 4 columns]

# %%
reload(episodes)
episodes.get_all_episodes(soups)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/Caskroom/mambaforge/base/lib/python3.10/importlib/__init__.py:139, in reload(module)
#     138 try:
# --> 139     name = module.__spec__.name
#     140 except AttributeError:
#
# File /usr/local/Caskroom/mambaforge/base/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute '__spec__'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File /usr/local/Caskroom/mambaforge/base/lib/python3.10/importlib/__init__.py:142, in reload(module)
#     141 try:
# --> 142     name = module.__name__
#     143 except AttributeError:
#
# ...

# %%
reload(w)
queens, queenep,episodes = w.get_show_data()

# %%
queens = queens[['queen_name','age','city','region','series','season','outcome']]
queens
# Out:
#             queen_name  age             city              region  \
# 0    BeBe Zahara Benet   28      Minneapolis           Minnesota
# 1         Nina Flowers   34           Denver            Colorado
# 2    Rebecca Glasscock   26  Fort Lauderdale             Florida
# 3              Shannel   29        Las Vegas              Nevada
# 4               Ongina   26      Los Angeles          California
# ..                 ...  ...              ...                 ...
# 351              Elips   25         Bordeaux  Nouvelle-Aquitaine
# 352           Kam Hugh   22            Paris       Île-de-France
# 353        La Briochée   31        Palaiseau       Île-de-France
# 354        Lova Ladiva   32         Toulouse           Occitania
# 355          La Kahena   29            Paris       Île-de-France
#
#                  series  season     outcome
# 0    Rupaul's Drag Race       1      Winner
# 1    Rupaul's Drag Race       1   Runner-up
# 2    Rupaul's Drag Race       1   3rd place
# ...
